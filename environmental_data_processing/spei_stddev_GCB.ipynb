# %% [markdown]
# ## Description
# Main python script used to assess climate characteristics and adaptation measures in Pisor, Touma et al. (in prep)<br>
# Sricpts by [Danielle Touma](danielletouma.com)<br>
# Run script in Jupyter Notebook or platform with *.ipynb capabilities.

# %% [markdown]
# ### External functions
# [find_runs.py](https://gist.github.com/alimanfoo/c5977e87111abe8127453b21204c1065)

# %% [markdown]
# ## Main script

# %% [markdown]
# ### Import packages/libraries

# %%
# analysis packages
import numpy as np
import pandas as pd
from scipy.ndimage import label, binary_dilation, generate_binary_structure
from find_runs import * # function found in find_runs.py
import xarray as xr
import xesmf as xe
import matplotlib.pyplot as plt
from scipy.stats import wilcoxon
from statsmodels.tsa.stattools import acf
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# ### Basic set up

# %% [markdown]
# Initialize directories where you can find the precipitation dataset (dir_month),
# the threshold dataset (dir_pxx), shapefile (dir_shp), and remittance data (dir_rem), and
# where figures should be output (dir_fig).

# %%
dir_spei = "/disk/dtouma/CEDA/"
dir_ndvi = "/disk/dtouma/NDVI/Africa/monthly_average/"
dir_fig = "/disk/dtouma/figures/"
dir_shp =  "/disk/dtouma/shapefiles/"
dir_rem = "/disk/dtouma/remittance/"
dir_out = "/disk/dtouma/remittance/GCB_paper_csvs/stddevs/"
dir_regions = "/disk/dtouma/remittance/country_csvs/"
dir_lights =  '/disk/dtouma/nightlights/'

# %%
period_year0 = [1995, 2000, 2005] #start year of period
period_year1 = [2009, 2009, 2009] #end year of period
nperiods = len(period_year0) # number of periods

# %% [markdown]
# ### Read in SPEI files
#
# We use CHIRPS-hPET SPEI Data.
#
# More info:
#
# Website for download: https://catalogue.ceda.ac.uk/uuid/ac43da11867243a1bb414e1637802dec
# paper: https://essd.copernicus.org/articles/15/5449/2023/
#
# Available datasets:
# SPEI from 1 to 48 months. 1981-2022. Global.
#
# Precipitation datasets:
# - CHIRPS (0.05 degrees)
# - MSWEP (0.25 degrees)
# - CRU-TS (0.5 degrees)
#
# PET datasts:
# - GLEAM (Priestley–Taylor equation; satellite & reanalysis data; 0.25 degrees)
# - hPET (Penman Monteith equation; ERA5-Land reanalysis; 0.1 degrees)
# - CRU-TS (Penman Monteith equation; CRU-TS; 0.5 degrees)
#
# SPEI datasets:
# CHIRPS_GLEAM, CHIRPS_hPET, MSWEP_GLEAM, MSWEP_hPET. All are statistically interpolated to 0.05 degrees.
#
# **We use the CHIRPS_GLEAM dataset at 0.05 resolution, already subset for Africa, for 1-, 3-, 6- and 12-month SPEI.**

# %%
# Reading subsetted Africa SPEI for different time scales:
# 1-, 3-, 6- and 12-month SPEI.
# This will allow us to better understand different timescales of drought

spei_time_scales = [3, 12] #[1, 3, 6, 12]
spei_file_list = []
for tt in spei_time_scales:
    spei_file_list.append(dir_spei+'Africa_spei'+"%02d" % (tt,)+'.nc')

spei_all_xr = xr.open_mfdataset(spei_file_list, combine='nested' ,concat_dim='time_scale')

# %%
# subsetting for time period until survey year since that is what people feel "climatologically"
survey_year = 2009
spei_all_years = spei_all_xr.time.dt.year
year0 = int(spei_all_years[0])
spei_sub_xr = spei_all_xr.sel(time=spei_all_xr.time.dt.year.isin(np.arange(year0,survey_year+1,1)))

# convert xarray into numpy array
spei_sub_np = np.array(spei_sub_xr.spei)
# Out:
# /home/staff/dtouma/miniconda3/envs/climenv/lib/python3.12/site-packages/xarray/core/indexing.py:1443: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]

# %% [markdown]
# Initialize variables that describe the dimensions of your SPEI dataset.

# %%
time_xr = spei_sub_xr.time
lon_xr = spei_sub_xr.lon 
lat_xr = spei_sub_xr.lat 

nlat = len(lat_xr)
nlon = len(lon_xr)
ntime = len(time_xr)

lon = np.array(lon_xr)
lat = np.array(lat_xr)

# %% [markdown]
# Calculate grid area for dataset

# %%
lat_sep = lat[1]-lat[0]
lon_sep = lon[1]-lon[0]

def gridsize(lat1, lon1, lat2, lon2):
   #https://en.wikipedia.org/wiki/Haversine_formula
   #https://stackoverflow.com/questions/639695/how-to-convert-latitude-or-longitude-to-meters/11172685#11172685
   R = 6378.137 # // Radius of earth in km
   dLat = lat2 * np.pi / 180 - lat1 * np.pi / 180
   dLon = lon2 * np.pi / 180 - lon1 * np.pi / 180
   a = np.sin(dLat/2) * np.sin(dLat/2) + np.cos(lat1 * np.pi / 180) * np.cos(lat2 * np.pi / 180) * np.sin(dLon/2) * np.sin(dLon/2)
   c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1-a))
   d = R * c
   return d * 1000 #; // meters

grid_area = np.zeros(shape=(nlat,nlon))

for ii in range(0,nlat,1):
   for jj in range(0,nlon,1):
      grid_area[ii,jj] = gridsize((lat[ii]-(lat_sep/2)),(lon[jj]-(lon_sep/2)),
                                  (lat[ii]+(lat_sep/2)),(lon[jj]+(lon_sep/2)))

# %% [markdown]
# ### Read in NDVI monthly average file<br>
# NDVI monthly data for Africa has been processed from global daily files (subset spatially and temporally averaged). <br>
# Original netCDF files are downloaded from NOAA Climate Data Record (CDR) of AVHRR Normalized Difference Vegetation Index (NDVI), Version 5 (https://www.ncei.noaa.gov/metadata/geoportal/rest/metadata/item/gov.noaa.ncdc:C01558/html). <br> Processing was done in CDO - a command line language that can be used to process netCDF files. <br> The average monthly file that was used in this study can be found on the Zenodo for the paper: [Zenodo link].

# %%
year0_ndvi = 1982
year1_ndvi = 2009

ndvi_xr = xr.open_dataset(dir_ndvi+'AVHRR-Land_v005_AVH13C1_NOAA_'+str(year0_ndvi)+'-'+str(year1_ndvi)+'_monthly_average_Africa.nc')
# Out:
# /home/staff/dtouma/miniconda3/envs/climenv/lib/python3.12/site-packages/xarray/coding/times.py:254: RuntimeWarning: invalid value encountered in cast
#   flat_num_dates_ns_int = (flat_num_dates * _NS_PER_TIME_DELTA[delta]).astype(

# %% [markdown]
# Calculate annual mean NDVI

# %%
ndvi_annual_mean = ndvi_xr.NDVI.groupby('time.year').mean('time')

# %% [markdown]
# Calculate SVI (Standardized vegetation index)<br>
# $SVI = (NDVI_{t,i,j} - \mu_{i,j})/ \sigma_{i,j}$<br>
# The SVI reflects if the vegetation is relatively healthy (>0; wet conditions) or relatively unhealthy (<0; drought conditions).

# %%
# find monthly mean and standard deviation across all dataset
ndvi_mu_month = ndvi_xr.NDVI.groupby('time.month').mean('time')
ndvi_sig_month = ndvi_xr.NDVI.groupby('time.month').std('time')
# standardize using (NDVI - mu)/sigma
SVI = (ndvi_xr.NDVI - ndvi_mu_month.sel(month=ndvi_xr.NDVI.time.dt.month))/ndvi_sig_month.sel(month=ndvi_xr.NDVI.time.dt.month)

# %% [markdown]
# ### Regrid SVI and NDVI to SPEI grid

# %% [markdown]
# Build regridder

# %%
ds_out = xr.Dataset(
    {
        "lat": spei_sub_xr.lat,
        "lon": spei_sub_xr.lon,
    }
)

regridder = xe.Regridder(SVI, ds_out, "bilinear")

# %% [markdown]
# regrid SVI, NDVI, and NDVI annual mean using regridder

# %%
SVI_regridded = regridder(SVI)
NDVI_regridded = regridder(ndvi_xr.NDVI)
NDVI_annual_mean_regridded = regridder(ndvi_annual_mean)

# %%
SVI_regridded_np = np.array(SVI_regridded)
NDVI_regridded_np = np.array(NDVI_regridded)
NDVI_annual_regridded_np = np.array(NDVI_annual_mean_regridded)

# %% [markdown]
# Pad the arrays so that the time dimension is the same as the SPEI array. In this case, the NDVI data starts one year after the SPEI, so we have a whole year of missing SVI values in 1981.

# %%
SVI_regridded_np_padded = np.pad(SVI_regridded_np, [(12, 0), (0, 0), (0, 0)], mode='constant', constant_values=-999999)
SVI_regridded_np_padded = np.ma.masked_where(SVI_regridded_np_padded==-999999, SVI_regridded_np_padded)
NDVI_regridded_np_padded = np.pad(NDVI_regridded_np, [(12, 0), (0, 0), (0, 0)], mode='constant', constant_values=-999999)
NDVI_regridded_np_padded = np.ma.masked_where(NDVI_regridded_np_padded==-999999, NDVI_regridded_np_padded)
NDVI_annual_regridded_np_padded = np.pad(NDVI_annual_regridded_np, [(12, 0), (0, 0), (0, 0)], mode='constant', constant_values=-999999)
NDVI_annual_regridded_np_padded = np.ma.masked_where(NDVI_annual_regridded_np_padded==-999999, NDVI_annual_regridded_np_padded)

# %%
period_NDVI_mean = np.full(fill_value=-999.0,shape=(nperiods,nlat,nlon))
for pp in range(0,nperiods,1):
    print('period = '+str(pp))
    period_year_inds = np.where((time_xr.dt.year>=period_year0[pp])&(time_xr.dt.year<=period_year1[pp]))[0]
    period_NDVI_mean[pp,:,:] = np.ma.mean(NDVI_regridded_np_padded[period_year_inds,:,:], axis=0)
# Out:
# period = 0
# period = 1
# period = 2

# %% [markdown]
# #### Finding droughts and calculating frequency, DIMS, and spatial extent.

# %% [markdown]
# Create a binary variable storing whether or not a pixel is below a certain drought threshold (1 = drought, 0 = no drought) for a standard deviation theshold.

# %% [markdown]
# Create SPEI binary dataset based on standard deviation

# %%
stddev = -1.5

spei_binary_stddev = np.zeros((len(spei_time_scales),
                        ntime,
                        nlat,
                        nlon,),
                        dtype=int)

for mm in range(0,ntime,1):
    if (mm%12==0):
        print(str(mm+1)+' out of '+ str(ntime))
    stddev_inds = np.where(spei_sub_np[:,mm,:,:]<=stddev)
    spei_binary_stddev[stddev_inds[0],mm,stddev_inds[1],stddev_inds[2]] = 1
# Out:
# 1 out of 348
# 13 out of 348
# 25 out of 348
# 37 out of 348
# 49 out of 348
# 61 out of 348
# 73 out of 348
# 85 out of 348
# 97 out of 348
# 109 out of 348
# 121 out of 348
# 133 out of 348
# 145 out of 348
# 157 out of 348
# 169 out of 348
# 181 out of 348
# 193 out of 348
# 205 out of 348
# 217 out of 348
# 229 out of 348
# 241 out of 348
# 253 out of 348
# 265 out of 348
# 277 out of 348
# 289 out of 348
# 301 out of 348
# 313 out of 348
# 325 out of 348
# 337 out of 348

# %% [markdown]
# Find one or more consecutive months with drought. drought_onsets = 1 when a drought starts over each grid point. drought_lengths = corresponding drought duration of that drought onset

# %% [markdown]
# New frequency calculation

# %%
period_timescale_ann_freq = np.zeros((len(spei_time_scales),nperiods,nlat,nlon))
for pp in range(0,nperiods,1):
    print('period = '+str(pp))
    period_year_inds = np.where((time_xr.dt.year>=period_year0[pp])&(time_xr.dt.year<=period_year1[pp]))[0]
    period_timescale_ann_freq[:,pp,:,:] = np.sum(spei_binary_stddev[:,period_year_inds,:,:], axis=1)/(period_year1[pp]-period_year0[pp]+1)
# Out:
# period = 0
# period = 1
# period = 2

# %% [markdown]
# Calculate ACF for each period and spei time scale

# %%
period_timescale_ACF = np.zeros((len(spei_time_scales),nperiods,nlat,nlon))
for pp in range(0,nperiods,1):
    print('period = '+str(pp))
    period_year_inds = np.where((time_xr.dt.year>=period_year0[pp])&(time_xr.dt.year<=period_year1[pp]))[0]
    for ii in range(0,nlat,1):
        if ii%50==0:
            print('lat = '+str(ii))
        for jj in range(0,nlon,1): 
            for tt in range(0,len(spei_time_scales),1):
                period_timescale_ACF[tt,pp,ii,jj] = acf(spei_binary_stddev[tt,period_year_inds,ii,jj] , nlags = spei_time_scales[tt])[spei_time_scales[tt]]
# Out:
# period = 0
# lat = 0
# /home/staff/dtouma/miniconda3/envs/climenv/lib/python3.12/site-packages/statsmodels/tsa/stattools.py:702: RuntimeWarning: invalid value encountered in divide
#   acf = avf[: nlags + 1] / avf[0]
# lat = 50
# lat = 100
# lat = 150
# lat = 200
# lat = 250
# lat = 300
# lat = 350
# lat = 400
# lat = 450
# lat = 500
# lat = 550
# lat = 600
# lat = 650
# lat = 700
# lat = 750
# lat = 800
# lat = 850
# lat = 900
# lat = 950
# lat = 1000
# lat = 1050
# lat = 1100
# lat = 1150
# lat = 1200
# lat = 1250
# lat = 1300
# lat = 1350
# lat = 1400
# period = 1
# lat = 0
# lat = 50
# lat = 100
# lat = 150
# lat = 200
# lat = 250
# lat = 300
# lat = 350
# lat = 400
# lat = 450
# lat = 500
# lat = 550
# lat = 600
# lat = 650
# lat = 700
# lat = 750
# lat = 800
# lat = 850
# lat = 900
# lat = 950
# lat = 1000
# lat = 1050
# lat = 1100
# lat = 1150
# lat = 1200
# lat = 1250
# lat = 1300
# lat = 1350
# lat = 1400
# period = 2
# lat = 0
# lat = 50
# lat = 100
# lat = 150
# lat = 200
# lat = 250
# lat = 300
# lat = 350
# lat = 400
# lat = 450
# lat = 500
# lat = 550
# lat = 600
# lat = 650
# lat = 700
# lat = 750
# lat = 800
# lat = 850
# lat = 900
# lat = 950
# lat = 1000
# lat = 1050
# lat = 1100
# lat = 1150
# lat = 1200
# lat = 1250
# lat = 1300
# lat = 1350
# lat = 1400

# %% [markdown]
# For each period, find the total *departure* of all drought months (*i<sub>1</sub>* and *i<sub>2</sub>* in Figure 1).

# %%
period_timescale_severity= np.full(fill_value = 999.0, shape=(len(spei_time_scales),nperiods, nlat, nlon) ,dtype=float) 

spei_departure = spei_sub_np - stddev

drought_departure = np.ma.masked_array(spei_departure,mask=((np.isnan(spei_departure))|(spei_binary_stddev==0)))

for pp in range(0,nperiods,1):
    print('period = '+str(pp))
    period_year_inds = np.where((time_xr.dt.year>=period_year0[pp])&(time_xr.dt.year<=period_year1[pp]))[0]
    period_timescale_severity[:,pp,:,:] = np.ma.mean(drought_departure[:,period_year_inds,:,:], axis=1)
# Out:
# period = 0
# period = 1
# period = 2

# %% [markdown]
# Find SVI severity for each timescale and period - mean over all drought months

# %%
period_timescale_SVI= np.full(fill_value = 999.0, shape=(len(spei_time_scales),nperiods, nlat, nlon) ,dtype=float) 

SVI_4d = np.broadcast_to(SVI_regridded_np_padded,spei_binary_stddev.shape) 

drought_SVI = np.ma.masked_array(SVI_4d,mask=(spei_binary_stddev==0))

for pp in range(0,nperiods,1):
    print('period = '+str(pp))
    period_year_inds = np.where((time_xr.dt.year>=period_year0[pp])&(time_xr.dt.year<=period_year1[pp]))[0]
    period_timescale_SVI[:,pp,:,:] = np.ma.mean(drought_SVI[:,period_year_inds,:,:], axis=1)
# Out:
# period = 0
# period = 1
# period = 2

# %%
# Finding spatially connected droughts, or 'drought objects', object area, their total and mean intensity across the object.
# These objects are not connected in time, instead, each month has their own set of objects.

spei_stddev_object_ngrids = np.zeros(shape=(len(spei_time_scales),ntime,nlat,nlon), dtype='int')
spei_stddev_object_area_m2 = np.zeros(shape=(len(spei_time_scales),ntime,nlat,nlon)) 
spei_stddev_nobjects = np.zeros((len(spei_time_scales),ntime), dtype='int')

# user defined structures for finding connected objects
l_structure = [[1,1,1],[1,1,1],[1,1,1]] # structure for finding connected areas - this structure allows edges and vertices to be connected (queen's case) 

for tt in range(0,len(spei_time_scales),1):
     print(str(spei_time_scales[tt])+'-month SPEI')
     for mm in range(0,ntime,1):
          mm_binary = spei_binary_stddev[tt,mm,:,:]
          mm_labels, mm_nlabels = label(mm_binary, structure=l_structure)
          spei_stddev_nobjects[tt,mm] = mm_nlabels
          print(str(mm)+' out of '+str(ntime)+' months: '+str(mm_nlabels))
          for obj in range(0,mm_nlabels,1):
               obj_inds = np.where(mm_labels==(obj+1))
               spei_stddev_object_ngrids[tt,mm,obj_inds[0],obj_inds[1]] = len(obj_inds[0])
               spei_stddev_object_area_m2[tt,mm,obj_inds[0],obj_inds[1]] = np.sum(grid_area[obj_inds[0],obj_inds[1]])
# Out:
# 3-month SPEI
# 0 out of 348 months: 0
# 1 out of 348 months: 0
# 2 out of 348 months: 41
# 3 out of 348 months: 34
# 4 out of 348 months: 41
# 5 out of 348 months: 86
# 6 out of 348 months: 50
# 7 out of 348 months: 85
# 8 out of 348 months: 87
# 9 out of 348 months: 125
# 10 out of 348 months: 181
# 11 out of 348 months: 206
# 12 out of 348 months: 147
# 13 out of 348 months: 38
# 14 out of 348 months: 85
# 15 out of 348 months: 115
# 16 out of 348 months: 69
# 17 out of 348 months: 72
# 18 out of 348 months: 130
# 19 out of 348 months: 293
# 20 out of 348 months: 350
# 21 out of 348 months: 193
# 22 out of 348 months: 224
# 23 out of 348 months: 125
# 24 out of 348 months: 281
# 25 out of 348 months: 277
# 26 out of 348 months: 437
# 27 out of 348 months: 605
# 28 out of 348 months: 598
# 29 out of 348 months: 284
# 30 out of 348 months: 274
# 31 out of 348 months: 411
# 32 out of 348 months: 550
# 33 out of 348 months: 487
# 34 out of 348 months: 392
# 35 out of 348 months: 223
# 36 out of 348 months: 255
# 37 out of 348 months: 446
# 38 out of 348 months: 446
# 39 out of 348 months: 562
# 40 out of 348 months: 302
# 41 out of 348 months: 267
# 42 out of 348 months: 316
# 43 out of 348 months: 223
# 44 out of 348 months: 183
# 45 out of 348 months: 257
# 46 out of 348 months: 339
# 47 out of 348 months: 258
# 48 out of 348 months: 82
# 49 out of 348 months: 161
# 50 out of 348 months: 73
# 51 out of 348 months: 44
# 52 out of 348 months: 128
# 53 out of 348 months: 145
# 54 out of 348 months: 102
# 55 out of 348 months: 109
# 56 out of 348 months: 70
# 57 out of 348 months: 245
# 58 out of 348 months: 290
# 59 out of 348 months: 252
# 60 out of 348 months: 93
# 61 out of 348 months: 64
# 62 out of 348 months: 75
# 63 out of 348 months: 83
# 64 out of 348 months: 165
# 65 out of 348 months: 265
# 66 out of 348 months: 259
# 67 out of 348 months: 413
# 68 out of 348 months: 266
# 69 out of 348 months: 317
# 70 out of 348 months: 163
# 71 out of 348 months: 137
# 72 out of 348 months: 95
# 73 out of 348 months: 179
# 74 out of 348 months: 175
# 75 out of 348 months: 200
# 76 out of 348 months: 346
# 77 out of 348 months: 327
# 78 out of 348 months: 364
# 79 out of 348 months: 253
# 80 out of 348 months: 296
# 81 out of 348 months: 240
# 82 out of 348 months: 313
# 83 out of 348 months: 382
# 84 out of 348 months: 223
# 85 out of 348 months: 379
# 86 out of 348 months: 284
# 87 out of 348 months: 355
# 88 out of 348 months: 250
# 89 out of 348 months: 222
# 90 out of 348 months: 136
# 91 out of 348 months: 49
# 92 out of 348 months: 64
# 93 out of 348 months: 109
# 94 out of 348 months: 108
# 95 out of 348 months: 198
# 96 out of 348 months: 179
# 97 out of 348 months: 246
# 98 out of 348 months: 239
# 99 out of 348 months: 147
# 100 out of 348 months: 134
# 101 out of 348 months: 180
# 102 out of 348 months: 175
# 103 out of 348 months: 143
# 104 out of 348 months: 120
# 105 out of 348 months: 90
# 106 out of 348 months: 239
# 107 out of 348 months: 134
# 108 out of 348 months: 133
# 109 out of 348 months: 51
# 110 out of 348 months: 199
# 111 out of 348 months: 264
# 112 out of 348 months: 388
# 113 out of 348 months: 301
# 114 out of 348 months: 360
# 115 out of 348 months: 422
# 116 out of 348 months: 318
# 117 out of 348 months: 354
# 118 out of 348 months: 449
# 119 out of 348 months: 331
# 120 out of 348 months: 161
# 121 out of 348 months: 56
# 122 out of 348 months: 65
# 123 out of 348 months: 188
# 124 out of 348 months: 94
# 125 out of 348 months: 125
# 126 out of 348 months: 129
# 127 out of 348 months: 273
# 128 out of 348 months: 350
# 129 out of 348 months: 459
# 130 out of 348 months: 503
# 131 out of 348 months: 265
# 132 out of 348 months: 301
# 133 out of 348 months: 396
# 134 out of 348 months: 547
# 135 out of 348 months: 560
# 136 out of 348 months: 292
# 137 out of 348 months: 205
# 138 out of 348 months: 204
# 139 out of 348 months: 222
# 140 out of 348 months: 275
# 141 out of 348 months: 296
# 142 out of 348 months: 226
# 143 out of 348 months: 245
# 144 out of 348 months: 170
# 145 out of 348 months: 111
# 146 out of 348 months: 96
# 147 out of 348 months: 160
# 148 out of 348 months: 192
# 149 out of 348 months: 196
# 150 out of 348 months: 248
# 151 out of 348 months: 328
# 152 out of 348 months: 347
# 153 out of 348 months: 351
# 154 out of 348 months: 261
# 155 out of 348 months: 238
# 156 out of 348 months: 267
# 157 out of 348 months: 267
# 158 out of 348 months: 306
# 159 out of 348 months: 319
# 160 out of 348 months: 268
# 161 out of 348 months: 300
# 162 out of 348 months: 185
# 163 out of 348 months: 194
# 164 out of 348 months: 100
# 165 out of 348 months: 77
# 166 out of 348 months: 131
# 167 out of 348 months: 218
# 168 out of 348 months: 281
# 169 out of 348 months: 256
# 170 out of 348 months: 220
# 171 out of 348 months: 151
# 172 out of 348 months: 225
# 173 out of 348 months: 211
# 174 out of 348 months: 200
# 175 out of 348 months: 155
# 176 out of 348 months: 213
# 177 out of 348 months: 172
# 178 out of 348 months: 348
# 179 out of 348 months: 180
# 180 out of 348 months: 224
# 181 out of 348 months: 320
# 182 out of 348 months: 222
# 183 out of 348 months: 350
# 184 out of 348 months: 172
# 185 out of 348 months: 309
# 186 out of 348 months: 219
# 187 out of 348 months: 344
# 188 out of 348 months: 279
# 189 out of 348 months: 331
# 190 out of 348 months: 413
# 191 out of 348 months: 355
# 192 out of 348 months: 186
# 193 out of 348 months: 194
# 194 out of 348 months: 203
# 195 out of 348 months: 137
# 196 out of 348 months: 118
# 197 out of 348 months: 37
# 198 out of 348 months: 265
# 199 out of 348 months: 356
# 200 out of 348 months: 524
# 201 out of 348 months: 266
# 202 out of 348 months: 53
# 203 out of 348 months: 12
# 204 out of 348 months: 7
# 205 out of 348 months: 59
# 206 out of 348 months: 241
# 207 out of 348 months: 515
# 208 out of 348 months: 525
# 209 out of 348 months: 689
# 210 out of 348 months: 416
# 211 out of 348 months: 195
# 212 out of 348 months: 119
# 213 out of 348 months: 190
# 214 out of 348 months: 412
# 215 out of 348 months: 420
# 216 out of 348 months: 269
# 217 out of 348 months: 170
# 218 out of 348 months: 71
# 219 out of 348 months: 163
# 220 out of 348 months: 216
# 221 out of 348 months: 417
# 222 out of 348 months: 158
# 223 out of 348 months: 70
# 224 out of 348 months: 48
# 225 out of 348 months: 78
# 226 out of 348 months: 68
# 227 out of 348 months: 111
# 228 out of 348 months: 204
# 229 out of 348 months: 426
# 230 out of 348 months: 418
# 231 out of 348 months: 430
# 232 out of 348 months: 222
# 233 out of 348 months: 129
# 234 out of 348 months: 76
# 235 out of 348 months: 116
# 236 out of 348 months: 67
# 237 out of 348 months: 92
# 238 out of 348 months: 112
# 239 out of 348 months: 50
# 240 out of 348 months: 96
# 241 out of 348 months: 81
# 242 out of 348 months: 88
# 243 out of 348 months: 85
# 244 out of 348 months: 78
# 245 out of 348 months: 92
# 246 out of 348 months: 99
# 247 out of 348 months: 114
# 248 out of 348 months: 187
# 249 out of 348 months: 198
# 250 out of 348 months: 193
# 251 out of 348 months: 155
# 252 out of 348 months: 84
# 253 out of 348 months: 94
# 254 out of 348 months: 70
# 255 out of 348 months: 84
# 256 out of 348 months: 170
# 257 out of 348 months: 207
# 258 out of 348 months: 313
# 259 out of 348 months: 190
# 260 out of 348 months: 168
# 261 out of 348 months: 130
# 262 out of 348 months: 144
# 263 out of 348 months: 77
# 264 out of 348 months: 90
# 265 out of 348 months: 49
# 266 out of 348 months: 128
# 267 out of 348 months: 92
# 268 out of 348 months: 164
# 269 out of 348 months: 107
# 270 out of 348 months: 97
# 271 out of 348 months: 77
# 272 out of 348 months: 95
# 273 out of 348 months: 116
# 274 out of 348 months: 173
# 275 out of 348 months: 196
# 276 out of 348 months: 41
# 277 out of 348 months: 223
# 278 out of 348 months: 310
# 279 out of 348 months: 298
# 280 out of 348 months: 207
# 281 out of 348 months: 161
# 282 out of 348 months: 242
# 283 out of 348 months: 208
# 284 out of 348 months: 166
# 285 out of 348 months: 221
# 286 out of 348 months: 182
# 287 out of 348 months: 85
# 288 out of 348 months: 45
# 289 out of 348 months: 101
# 290 out of 348 months: 134
# 291 out of 348 months: 163
# 292 out of 348 months: 158
# 293 out of 348 months: 159
# 294 out of 348 months: 147
# 295 out of 348 months: 182
# 296 out of 348 months: 222
# 297 out of 348 months: 198
# 298 out of 348 months: 299
# 299 out of 348 months: 223
# 300 out of 348 months: 159
# 301 out of 348 months: 160
# 302 out of 348 months: 94
# 303 out of 348 months: 61
# 304 out of 348 months: 58
# 305 out of 348 months: 90
# 306 out of 348 months: 129
# 307 out of 348 months: 97
# 308 out of 348 months: 94
# 309 out of 348 months: 123
# 310 out of 348 months: 64
# 311 out of 348 months: 106
# 312 out of 348 months: 167
# 313 out of 348 months: 161
# 314 out of 348 months: 220
# 315 out of 348 months: 112
# 316 out of 348 months: 163
# 317 out of 348 months: 170
# 318 out of 348 months: 245
# 319 out of 348 months: 131
# 320 out of 348 months: 120
# 321 out of 348 months: 99
# 322 out of 348 months: 165
# 323 out of 348 months: 166
# 324 out of 348 months: 63
# 325 out of 348 months: 347
# 326 out of 348 months: 290
# 327 out of 348 months: 381
# 328 out of 348 months: 171
# 329 out of 348 months: 174
# 330 out of 348 months: 126
# 331 out of 348 months: 90
# 332 out of 348 months: 155
# 333 out of 348 months: 217
# 334 out of 348 months: 214
# 335 out of 348 months: 149
# 336 out of 348 months: 130
# 337 out of 348 months: 78
# 338 out of 348 months: 85
# 339 out of 348 months: 114
# 340 out of 348 months: 158
# 341 out of 348 months: 178
# 342 out of 348 months: 325
# 343 out of 348 months: 238
# 344 out of 348 months: 277
# 345 out of 348 months: 198
# 346 out of 348 months: 198
# 347 out of 348 months: 90
# 12-month SPEI
# 0 out of 348 months: 0
# 1 out of 348 months: 0
# 2 out of 348 months: 0
# 3 out of 348 months: 0
# 4 out of 348 months: 0
# 5 out of 348 months: 0
# 6 out of 348 months: 0
# 7 out of 348 months: 0
# 8 out of 348 months: 0
# 9 out of 348 months: 0
# 10 out of 348 months: 0
# 11 out of 348 months: 103
# 12 out of 348 months: 112
# 13 out of 348 months: 98
# 14 out of 348 months: 135
# 15 out of 348 months: 88
# 16 out of 348 months: 102
# 17 out of 348 months: 82
# 18 out of 348 months: 176
# 19 out of 348 months: 198
# 20 out of 348 months: 220
# 21 out of 348 months: 164
# 22 out of 348 months: 116
# 23 out of 348 months: 138
# 24 out of 348 months: 214
# 25 out of 348 months: 253
# 26 out of 348 months: 308
# 27 out of 348 months: 374
# 28 out of 348 months: 439
# 29 out of 348 months: 430
# 30 out of 348 months: 509
# 31 out of 348 months: 438
# 32 out of 348 months: 471
# 33 out of 348 months: 483
# 34 out of 348 months: 447
# 35 out of 348 months: 498
# 36 out of 348 months: 488
# 37 out of 348 months: 621
# 38 out of 348 months: 565
# 39 out of 348 months: 620
# 40 out of 348 months: 637
# 41 out of 348 months: 650
# 42 out of 348 months: 590
# 43 out of 348 months: 451
# 44 out of 348 months: 507
# 45 out of 348 months: 565
# 46 out of 348 months: 557
# 47 out of 348 months: 532
# 48 out of 348 months: 495
# 49 out of 348 months: 347
# 50 out of 348 months: 319
# 51 out of 348 months: 203
# 52 out of 348 months: 176
# 53 out of 348 months: 185
# 54 out of 348 months: 200
# 55 out of 348 months: 109
# 56 out of 348 months: 61
# 57 out of 348 months: 106
# 58 out of 348 months: 116
# 59 out of 348 months: 123
# 60 out of 348 months: 112
# 61 out of 348 months: 91
# 62 out of 348 months: 96
# 63 out of 348 months: 76
# 64 out of 348 months: 62
# 65 out of 348 months: 74
# 66 out of 348 months: 146
# 67 out of 348 months: 283
# 68 out of 348 months: 210
# 69 out of 348 months: 158
# 70 out of 348 months: 174
# 71 out of 348 months: 196
# 72 out of 348 months: 200
# 73 out of 348 months: 176
# 74 out of 348 months: 232
# 75 out of 348 months: 336
# 76 out of 348 months: 360
# 77 out of 348 months: 287
# 78 out of 348 months: 390
# 79 out of 348 months: 247
# 80 out of 348 months: 257
# 81 out of 348 months: 322
# 82 out of 348 months: 272
# 83 out of 348 months: 357
# 84 out of 348 months: 283
# 85 out of 348 months: 527
# 86 out of 348 months: 519
# 87 out of 348 months: 504
# 88 out of 348 months: 521
# 89 out of 348 months: 528
# 90 out of 348 months: 423
# 91 out of 348 months: 342
# 92 out of 348 months: 342
# 93 out of 348 months: 380
# 94 out of 348 months: 321
# 95 out of 348 months: 306
# 96 out of 348 months: 306
# 97 out of 348 months: 126
# 98 out of 348 months: 91
# 99 out of 348 months: 114
# 100 out of 348 months: 92
# 101 out of 348 months: 86
# 102 out of 348 months: 101
# 103 out of 348 months: 114
# 104 out of 348 months: 162
# 105 out of 348 months: 149
# 106 out of 348 months: 132
# 107 out of 348 months: 127
# 108 out of 348 months: 113
# 109 out of 348 months: 85
# 110 out of 348 months: 129
# 111 out of 348 months: 102
# 112 out of 348 months: 88
# 113 out of 348 months: 157
# 114 out of 348 months: 165
# 115 out of 348 months: 409
# 116 out of 348 months: 397
# 117 out of 348 months: 436
# 118 out of 348 months: 358
# 119 out of 348 months: 356
# 120 out of 348 months: 330
# 121 out of 348 months: 342
# 122 out of 348 months: 284
# 123 out of 348 months: 274
# 124 out of 348 months: 173
# 125 out of 348 months: 178
# 126 out of 348 months: 155
# 127 out of 348 months: 106
# 128 out of 348 months: 123
# 129 out of 348 months: 123
# 130 out of 348 months: 132
# 131 out of 348 months: 166
# 132 out of 348 months: 209
# 133 out of 348 months: 468
# 134 out of 348 months: 476
# 135 out of 348 months: 489
# 136 out of 348 months: 594
# 137 out of 348 months: 562
# 138 out of 348 months: 530
# 139 out of 348 months: 551
# 140 out of 348 months: 453
# 141 out of 348 months: 463
# 142 out of 348 months: 444
# 143 out of 348 months: 561
# 144 out of 348 months: 446
# 145 out of 348 months: 224
# 146 out of 348 months: 187
# 147 out of 348 months: 151
# 148 out of 348 months: 181
# 149 out of 348 months: 177
# 150 out of 348 months: 220
# 151 out of 348 months: 204
# 152 out of 348 months: 191
# 153 out of 348 months: 226
# 154 out of 348 months: 249
# 155 out of 348 months: 221
# 156 out of 348 months: 253
# 157 out of 348 months: 296
# 158 out of 348 months: 414
# 159 out of 348 months: 519
# 160 out of 348 months: 489
# 161 out of 348 months: 486
# 162 out of 348 months: 412
# 163 out of 348 months: 349
# 164 out of 348 months: 352
# 165 out of 348 months: 334
# 166 out of 348 months: 274
# 167 out of 348 months: 263
# 168 out of 348 months: 235
# 169 out of 348 months: 219
# 170 out of 348 months: 183
# 171 out of 348 months: 147
# 172 out of 348 months: 172
# 173 out of 348 months: 167
# 174 out of 348 months: 179
# 175 out of 348 months: 168
# 176 out of 348 months: 225
# 177 out of 348 months: 209
# 178 out of 348 months: 259
# 179 out of 348 months: 316
# 180 out of 348 months: 235
# 181 out of 348 months: 400
# 182 out of 348 months: 372
# 183 out of 348 months: 397
# 184 out of 348 months: 349
# 185 out of 348 months: 371
# 186 out of 348 months: 370
# 187 out of 348 months: 363
# 188 out of 348 months: 338
# 189 out of 348 months: 419
# 190 out of 348 months: 421
# 191 out of 348 months: 395
# 192 out of 348 months: 402
# 193 out of 348 months: 336
# 194 out of 348 months: 390
# 195 out of 348 months: 259
# 196 out of 348 months: 246
# 197 out of 348 months: 189
# 198 out of 348 months: 234
# 199 out of 348 months: 287
# 200 out of 348 months: 299
# 201 out of 348 months: 231
# 202 out of 348 months: 140
# 203 out of 348 months: 44
# 204 out of 348 months: 71
# 205 out of 348 months: 52
# 206 out of 348 months: 89
# 207 out of 348 months: 153
# 208 out of 348 months: 175
# 209 out of 348 months: 365
# 210 out of 348 months: 224
# 211 out of 348 months: 125
# 212 out of 348 months: 118
# 213 out of 348 months: 142
# 214 out of 348 months: 222
# 215 out of 348 months: 277
# 216 out of 348 months: 322
# 217 out of 348 months: 392
# 218 out of 348 months: 258
# 219 out of 348 months: 244
# 220 out of 348 months: 279
# 221 out of 348 months: 279
# 222 out of 348 months: 263
# 223 out of 348 months: 271
# 224 out of 348 months: 259
# 225 out of 348 months: 208
# 226 out of 348 months: 209
# 227 out of 348 months: 131
# 228 out of 348 months: 141
# 229 out of 348 months: 341
# 230 out of 348 months: 400
# 231 out of 348 months: 389
# 232 out of 348 months: 370
# 233 out of 348 months: 374
# 234 out of 348 months: 359
# 235 out of 348 months: 389
# 236 out of 348 months: 342
# 237 out of 348 months: 363
# 238 out of 348 months: 395
# 239 out of 348 months: 313
# 240 out of 348 months: 315
# 241 out of 348 months: 155
# 242 out of 348 months: 109
# 243 out of 348 months: 52
# 244 out of 348 months: 59
# 245 out of 348 months: 36
# 246 out of 348 months: 52
# 247 out of 348 months: 84
# 248 out of 348 months: 129
# 249 out of 348 months: 158
# 250 out of 348 months: 125
# 251 out of 348 months: 149
# 252 out of 348 months: 123
# 253 out of 348 months: 96
# 254 out of 348 months: 154
# 255 out of 348 months: 91
# 256 out of 348 months: 126
# 257 out of 348 months: 161
# 258 out of 348 months: 202
# 259 out of 348 months: 199
# 260 out of 348 months: 191
# 261 out of 348 months: 118
# 262 out of 348 months: 197
# 263 out of 348 months: 173
# 264 out of 348 months: 151
# 265 out of 348 months: 150
# 266 out of 348 months: 210
# 267 out of 348 months: 196
# 268 out of 348 months: 157
# 269 out of 348 months: 129
# 270 out of 348 months: 139
# 271 out of 348 months: 120
# 272 out of 348 months: 119
# 273 out of 348 months: 124
# 274 out of 348 months: 133
# 275 out of 348 months: 117
# 276 out of 348 months: 135
# 277 out of 348 months: 348
# 278 out of 348 months: 302
# 279 out of 348 months: 288
# 280 out of 348 months: 343
# 281 out of 348 months: 351
# 282 out of 348 months: 422
# 283 out of 348 months: 441
# 284 out of 348 months: 449
# 285 out of 348 months: 408
# 286 out of 348 months: 389
# 287 out of 348 months: 356
# 288 out of 348 months: 410
# 289 out of 348 months: 200
# 290 out of 348 months: 241
# 291 out of 348 months: 253
# 292 out of 348 months: 214
# 293 out of 348 months: 186
# 294 out of 348 months: 223
# 295 out of 348 months: 162
# 296 out of 348 months: 188
# 297 out of 348 months: 189
# 298 out of 348 months: 291
# 299 out of 348 months: 248
# 300 out of 348 months: 191
# 301 out of 348 months: 187
# 302 out of 348 months: 200
# 303 out of 348 months: 218
# 304 out of 348 months: 150
# 305 out of 348 months: 159
# 306 out of 348 months: 191
# 307 out of 348 months: 156
# 308 out of 348 months: 136
# 309 out of 348 months: 122
# 310 out of 348 months: 93
# 311 out of 348 months: 68
# 312 out of 348 months: 73
# 313 out of 348 months: 60
# 314 out of 348 months: 127
# 315 out of 348 months: 64
# 316 out of 348 months: 156
# 317 out of 348 months: 124
# 318 out of 348 months: 124
# 319 out of 348 months: 103
# 320 out of 348 months: 155
# 321 out of 348 months: 145
# 322 out of 348 months: 129
# 323 out of 348 months: 144
# 324 out of 348 months: 120
# 325 out of 348 months: 334
# 326 out of 348 months: 301
# 327 out of 348 months: 315
# 328 out of 348 months: 304
# 329 out of 348 months: 265
# 330 out of 348 months: 285
# 331 out of 348 months: 283
# 332 out of 348 months: 296
# 333 out of 348 months: 326
# 334 out of 348 months: 320
# 335 out of 348 months: 321
# 336 out of 348 months: 306
# 337 out of 348 months: 132
# 338 out of 348 months: 152
# 339 out of 348 months: 151
# 340 out of 348 months: 158
# 341 out of 348 months: 173
# 342 out of 348 months: 204
# 343 out of 348 months: 249
# 344 out of 348 months: 218
# 345 out of 348 months: 199
# 346 out of 348 months: 184
# 347 out of 348 months: 174

# %%
# period_timescale_max_area_drought_event = np.full(fill_value = -999.0, shape=(len(spei_time_scales),nperiods, nlat, nlon) ,dtype=float)
period_timescale_avg_area = np.full(fill_value = -999.0, shape=(len(spei_time_scales),nperiods, nlat, nlon) ,dtype=float)

# drought_area = spei_perc_object_area_m2 * spei_binary_perc
drought_area_masked = np.ma.masked_array(spei_stddev_object_area_m2,mask=(spei_binary_stddev==0))

for pp in range(0,nperiods,1):
    print('period = '+str(pp))
    period_year_inds = np.where((time_xr.dt.year>=period_year0[pp])&(time_xr.dt.year<=period_year1[pp]))[0]
    period_timescale_avg_area[:,pp,:,:] = np.ma.mean(drought_area_masked[:,period_year_inds,:,:], axis=1)
# Out:
# period = 0
# period = 1
# period = 2

# %% [markdown]
# ### Calculate frequency, DIMS, dispersion, SVI severity, and area for selected periods.

# %% [markdown]
# ### Nighttime Lights City Centers
#
# Find closest population centers using processed night time lights. nighttime_lights.csv can be found in the GitHub.

# %%
lights_df = pd.read_csv(dir_lights+'nighttime_lights.csv')

# %%
# This function allows us to find the closest city center location - will be used in loop at the end.
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return array[idx]

# %% [markdown]
# For each region and period, read in remittance data, merge with SPEI data, ensure NDVI is not NAN, find population centers, save output file.

# %%
regions = ['nigeria','kenya','burkina faso','south africa', 'uganda','senegal']

# for "regridding" survey lat/longs to SPEI lat/longs
precision = 2
base = 0.05

NDVI_search_radius = 30
sev_search_radius = 30

# create SPEI data frame
lat_2d = np.repeat(np.around(lat, decimals=2),len(lon))
lon_2d = np.tile(np.around(lon, decimals=2),len(lat))

#select period
for pp in range(0,nperiods,1):
    print(str(period_year0[pp])+'-'+str(period_year1[pp]))
    for tt in range(0,len(spei_time_scales),1):
        print(str(spei_time_scales[tt])+'-month SPEI')
        spei_df = pd.DataFrame({
            'lat_SPEI':lat_2d,'long_SPEI':lon_2d,
            'annual_frequency': period_timescale_ann_freq[tt,pp,:,:].flat,
            'severity': period_timescale_severity[tt,pp,:,:].flat,
            'autocorrelation': period_timescale_ACF[tt,pp,:,:].flat,
            'avg_area': period_timescale_avg_area[tt,pp,:,:].flat,
            'NDVI_mean': period_NDVI_mean[pp,:,:].flat,
            'SVI_severity': period_timescale_SVI[tt,pp,:,:].flat,
            })
        for rr in regions:
            print(rr)
            remit_df = pd.read_csv(dir_regions+rr+'.csv', encoding = "ISO-8859-1")
            existing_columns = list(set(remit_df.columns) & set(spei_df.columns))
            remit_df = remit_df.drop(columns=existing_columns)
            if 'lat_regrid' in remit_df.columns:
                remit_df = remit_df.drop(columns=['lat_regrid','long_regrid'])
            remit_lat = np.array(remit_df['lat'])
            remit_lat_rounded = np.round(base*np.round(remit_lat/base), decimals=precision)
            remit_lon = np.array(remit_df['long'])
            remit_lon_rounded = np.round(base*np.round(remit_lon/base), decimals=precision)
            remit_df['lat_SPEI'] = remit_lat_rounded
            remit_df['long_SPEI'] = remit_lon_rounded
            remit_df['NDVI_lat'] = remit_df['lat_SPEI']
            remit_df['NDVI_lon'] = remit_df['long_SPEI']
            remit_df['sev_lat'] = remit_df['lat_SPEI']
            remit_df['sev_lon'] = remit_df['long_SPEI']
            #city centers (nighttime lights)
            region_lights_df = lights_df[lights_df['NAME_0']==rr.title()].reset_index(drop=True)
            lights_lat = region_lights_df['latitude']
            lights_lon = region_lights_df['longitude']
            remit_lat_nearest = np.zeros(len(remit_lat))
            for ii in range(0,len(remit_lat),1):
                remit_lat_nearest[ii] = find_nearest(lights_lat,remit_lat[ii])
            remit_lon_nearest = np.zeros(len(remit_lon))
            for jj in range(0,len(remit_lon),1):
                remit_lon_nearest[jj] = find_nearest(lights_lon,remit_lon[jj]) 
            remit_df['pop_cent_lat'] = remit_lat_nearest
            remit_df['pop_cent_long'] = remit_lon_nearest
            #merge remittance dataframe with spei dataframe by matching regridded lat longs
            spei_remit_df = pd.merge(remit_df,spei_df,how='left',on=['lat_SPEI','long_SPEI'])
            rows_with_nan_NDVI = spei_remit_df[(spei_remit_df['NDVI_mean'].isna())&~(spei_remit_df['lat'].isna())]
            print(str(len(rows_with_nan_NDVI)) + ' NDVI nans')
            if len(rows_with_nan_NDVI)>0:
                period_NDVI_mean_xr = xr.DataArray(period_NDVI_mean[pp,:,:],coords = {'lat' : spei_sub_xr.lat, 'lon' : spei_sub_xr.lon}, name='NDVI_period')
                # first try to fix using xarray find nearest using original lat long
                for nn in rows_with_nan_NDVI.index:
                    NDVI_missing = period_NDVI_mean_xr.sel(lat=rows_with_nan_NDVI.loc[nn]['lat'], lon = rows_with_nan_NDVI.loc[nn]['long'], method='nearest')
                    if np.isnan(NDVI_missing.values.item()):
                    # incrementally change lat and long until non-nan value is reached
                        for ii in np.arange(-1*NDVI_search_radius,NDVI_search_radius+1,1):
                            ii_check = period_NDVI_mean_xr.sel(lat=rows_with_nan_NDVI.loc[nn]['lat']+base*ii, lon = rows_with_nan_NDVI.loc[nn]['long'], method='nearest') 
                            if ~np.isnan(ii_check.values.item()):
                                spei_remit_df.at[nn,'NDVI_mean'] = ii_check.values.item()
                                spei_remit_df.at[nn,'NDVI_lat'] = ii_check.lat
                                spei_remit_df.at[nn,'NDVI_lon'] = ii_check.lon
                                break
                            else:
                                jj_check = period_NDVI_mean_xr.sel(lat=rows_with_nan_NDVI.loc[nn]['lat']+base*ii, lon = rows_with_nan_NDVI.loc[nn]['long']+base*ii, method='nearest')
                                if ~np.isnan(jj_check.values.item()):
                                    spei_remit_df.at[nn,'NDVI_mean'] = jj_check.values.item()
                                    spei_remit_df.at[nn,'NDVI_lat'] = jj_check.lat
                                    spei_remit_df.at[nn,'NDVI_lon'] = jj_check.lon
                                    break
                    else:
                        spei_remit_df.at[nn,'NDVI_mean'] = NDVI_missing.values.item()
                        spei_remit_df.at[nn,'NDVI_lat'] = NDVI_missing.lat
                        spei_remit_df.at[nn,'NDVI_lon'] = NDVI_missing.lon
            rows_with_nan_NDVI_after = spei_remit_df[(spei_remit_df['NDVI_mean'].isna())&~(spei_remit_df['lat'].isna())]
            print(str(len(rows_with_nan_NDVI_after)) + ' NDVI nans after')
            rows_with_nan_sev = spei_remit_df[(spei_remit_df['severity'].isna())&~(spei_remit_df['lat'].isna())]
            print(str(len(rows_with_nan_sev)) + ' sev nans')
            if len(rows_with_nan_sev)>0:
                period_timescale_severity_xr = xr.DataArray(period_timescale_severity[tt,pp,:,:],coords = {'lat' : spei_sub_xr.lat, 'lon' : spei_sub_xr.lon}, name='sev_period_timescale')
                # first try to fix using xarray find nearest using original lat long
                for nn in rows_with_nan_sev.index:
                    sev_missing = period_timescale_severity_xr.sel(lat=rows_with_nan_sev.loc[nn]['lat'], lon = rows_with_nan_sev.loc[nn]['long'], method='nearest')
                    if np.isnan(sev_missing.values.item()):
                    # incrementally change lat and long until non-nan value is reached
                        for ii in np.arange(-1*sev_search_radius,sev_search_radius+1,1):
                            ii_check = period_timescale_severity_xr.sel(lat=rows_with_nan_sev.loc[nn]['lat']+base*ii, lon = rows_with_nan_sev.loc[nn]['long'], method='nearest') 
                            if ~np.isnan(ii_check.values.item()):
                                spei_remit_df.at[nn,'severity'] = ii_check.values.item()
                                spei_remit_df.at[nn,'sev_lat'] = ii_check.lat
                                spei_remit_df.at[nn,'sev_lon'] = ii_check.lon
                                break
                            else:
                                jj_check = period_timescale_severity_xr.sel(lat=rows_with_nan_sev.loc[nn]['lat']+base*ii, lon = rows_with_nan_sev.loc[nn]['long']+base*ii, method='nearest')
                                if ~np.isnan(jj_check.values.item()):
                                    spei_remit_df.at[nn,'severity'] = jj_check.values.item()
                                    spei_remit_df.at[nn,'sev_lat'] = jj_check.lat
                                    spei_remit_df.at[nn,'sev_lon'] = jj_check.lon
                                    break
                    else:
                        spei_remit_df.at[nn,'severity'] = sev_missing.values.item()
                        spei_remit_df.at[nn,'sev_lat'] = sev_missing.lat
                        spei_remit_df.at[nn,'sev_lon'] = sev_missing.lon
            rows_with_nan_sev_after = spei_remit_df[(spei_remit_df['severity'].isna())&~(spei_remit_df['lat'].isna())]
            print(str(len(rows_with_nan_sev_after)) + ' severity nans after')
            #save CSV file
            spei_remit_df.to_csv(dir_out+rr.replace(" ","")+'_SPEI-'+str(spei_time_scales[tt])+'_'+str(period_year0[pp])+'-'+str(period_year1[pp])+'_'+str(stddev)+'stddev_'+str(year0)+'-'+str(survey_year)+'_means.csv')
# Out:
# 1995-2009
# 3-month SPEI
# nigeria
# 47 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# kenya
# 104 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# burkina faso
# 0 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# south africa
# 0 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# uganda
# 19 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# senegal
# 604 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# 12-month SPEI
# nigeria
# 47 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# kenya
# 104 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# burkina faso
# 0 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# south africa
# 0 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# uganda
# 19 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# senegal
# 604 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# 2000-2009
# 3-month SPEI
# nigeria
# 47 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# kenya
# 104 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# burkina faso
# 0 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# south africa
# 0 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# uganda
# 19 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# senegal
# 549 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# 12-month SPEI
# nigeria
# 47 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# kenya
# 104 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# burkina faso
# 0 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# south africa
# 0 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# uganda
# 19 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# senegal
# 549 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# 2005-2009
# 3-month SPEI
# nigeria
# 47 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# kenya
# 104 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# burkina faso
# 0 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# south africa
# 0 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# uganda
# 19 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# senegal
# 545 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# 12-month SPEI
# nigeria
# 47 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# kenya
# 104 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# burkina faso
# 0 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# south africa
# 0 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# uganda
# 19 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
# senegal
# 545 NDVI nans
# 0 NDVI nans after
# 0 sev nans
# 0 severity nans after
